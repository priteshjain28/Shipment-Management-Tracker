# %%
#Importing the packages
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
file_path = "C:/Users/prite_ef/OneDrive/Documents/Pyhton Practice/Supply Chain Data/8gx2fvg2k6-5/MetadataSCDatasets.csv"
na_vals=['NA', 'Missing']
df = pd.read_csv(file_path, encoding='latin-1',na_values=na_vals)

# %%
pd.set_option('display.max_columns',85) ## to change setting so that we can see all the col.
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
file_path = "C:/Users/prite_ef/OneDrive/Documents/Pyhton Practice/Supply Chain Data/8gx2fvg2k6-5/DescriptionDataCoSupplyChain.csv"

schema_df = pd.read_csv(file_path, encoding='latin-1')
pd.set_option('display.max_colwidth', 2000)

# %%
schema_df
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.shape
# Out:
# (180519, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.isna().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
schema_df
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
df.drop(columns=['Customer Email', 'Customer Password', 'Customer Id','Department Id','Order Customer Id','Order Id','Order Item Cardprod Id','Order Item Id','Order Zipcode','Product Card Id','Product Category Id','Product Description','Product Image'],inplace=True)

# %%
df.head(50)
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0      DEBIT                         3                              4
# 1   TRANSFER                         5                              4
# 2       CASH                         4                              4
# 3      DEBIT                         3                              4
# 4    PAYMENT                         2                              4
# 5   TRANSFER                         6                              4
# 6      DEBIT                         2                              1
# 7   TRANSFER                         2                              1
# 8       CASH                         3                              2
# 9       CASH                         2                              1
# 10  TRANSFER                         6                              2
# 11  TRANSFER                         5                              2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Fname                 180519 non-null  object
# ...

# %%
schema_df
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
new_column_name=['transaction_type','actual_shipping_days', 'scheduled_shipping_days','earnings_per_order', 'sales_per_customer', 'delivery_status', 'late_delivery', 'category_id','category_name','purchase_city','purchase_country','customer_first_name','customer_last_name','customer_segment','purchase_state','purchase_street','purchase_zipcode','department_category','latitude','longitude','market_region','order_city','order_country','order_date','order_item_discount','order_item_discount_rate','order_item_rate','order_item_profit_ratio','order_item_quantity','gross_sales_per_customer','net_sales_per_customer','net_profit_per_order','order_region','order_state','order_status',
                 'product_name','product_price',
            'product_availability','shipping_date','shipping_mode']
df.columns=new_column_name

# %%
df.drop(columns=['product_price'],inplace=True)

# %%
df
# Out:
#        transaction_type  actual_shipping_days  scheduled_shipping_days  \
# 0                 DEBIT                     3                        4
# 1              TRANSFER                     5                        4
# 2                  CASH                     4                        4
# 3                 DEBIT                     3                        4
# 4               PAYMENT                     2                        4
# ...                 ...                   ...                      ...
# 180514             CASH                     4                        4
# 180515            DEBIT                     3                        2
# 180516         TRANSFER                     5                        4
# 180517          PAYMENT                     3                        4
# 180518          PAYMENT                     4                        4
#
#         earnings_per_order  sales_per_customer   delivery_status  \
# ...

# %%
df.describe()
# Out:
#        actual_shipping_days  scheduled_shipping_days  earnings_per_order  \
# count         180519.000000            180519.000000       180519.000000
# mean               3.497654                 2.931847           21.974989
# std                1.623722                 1.374449          104.433526
# min                0.000000                 0.000000        -4274.979980
# 25%                2.000000                 2.000000            7.000000
# 50%                3.000000                 4.000000           31.520000
# 75%                5.000000                 4.000000           64.800003
# max                6.000000                 4.000000          911.799988
#
#        sales_per_customer  late_delivery    category_id  purchase_zipcode  \
# count       180519.000000  180519.000000  180519.000000     180516.000000
# mean           183.107609       0.548291      31.851451      35921.126914
# std            120.043670       0.497664      15.640064      37542.461122
# ...

# %%
df.describe(include = ['object'])
# Out:
#        transaction_type delivery_status category_name purchase_city  \
# count            180519          180519        180519        180519
# unique                4               4            50           563
# top               DEBIT   Late delivery        Cleats        Caguas
# freq              69295           98977         24551         66770
#
#        purchase_country customer_first_name customer_last_name  \
# count            180519              180519             180511
# unique                2                 782               1109
# top             EE. UU.                Mary              Smith
# freq             111146               65150              64104
#
#        customer_segment purchase_state          purchase_street  \
# count            180519         180519                   180519
# unique                3             46                     7458
# top            Consumer             PR  9126 Wishing Expressway
# ...

# %%
df.isnull().sum()
# Out:
# transaction_type            0
# actual_shipping_days        0
# scheduled_shipping_days     0
# earnings_per_order          0
# sales_per_customer          0
# delivery_status             0
# late_delivery               0
# category_id                 0
# category_name               0
# purchase_city               0
# purchase_country            0
# customer_first_name         0
# customer_last_name          8
# customer_segment            0
# purchase_state              0
# purchase_street             0
# purchase_zipcode            3
# department_category         0
# latitude                    0
# longitude                   0
# market_region               0
# order_city                  0
# order_country               0
# order_date                  0
# order_item_discount         0
# order_item_discount_rate    0
# order_item_rate             0
# order_item_profit_ratio     0
# order_item_quantity         0
# gross_sales_per_customer    0
# net_sales_per_customer      0
# ...

# %%
df['customer_last_name'].fillna("MISSING", inplace=True)

# %%
df.isnull().sum()
# Out:
# transaction_type            0
# actual_shipping_days        0
# scheduled_shipping_days     0
# earnings_per_order          0
# sales_per_customer          0
# delivery_status             0
# late_delivery               0
# category_id                 0
# category_name               0
# purchase_city               0
# purchase_country            0
# customer_first_name         0
# customer_last_name          0
# customer_segment            0
# purchase_state              0
# purchase_street             0
# purchase_zipcode            3
# department_category         0
# latitude                    0
# longitude                   0
# market_region               0
# order_city                  0
# order_country               0
# order_date                  0
# order_item_discount         0
# order_item_discount_rate    0
# order_item_rate             0
# order_item_profit_ratio     0
# order_item_quantity         0
# gross_sales_per_customer    0
# net_sales_per_customer      0
# ...

# %%
df[df['purchase_zipcode'].isna()].index
# Out:
# Int64Index([35704, 46440, 82511], dtype='int64')

# %%
df.loc[df[df['purchase_zipcode'].isna()].index]
# Out:
#       transaction_type  actual_shipping_days  scheduled_shipping_days  \
# 35704            DEBIT                     2                        1
# 46440          PAYMENT                     4                        4
# 82511            DEBIT                     4                        4
#
#        earnings_per_order  sales_per_customer   delivery_status  \
# 35704           66.379997          189.660004     Late delivery
# 46440           10.910000           38.959999  Shipping on time
# 82511           59.990002          299.959992  Shipping on time
#
#        late_delivery  category_id         category_name purchase_city  \
# 35704              1           65  Consumer Electronics            CA
# 46440              0           75           Video Games            CA
# 82511              0           63   Children's Clothing            CA
#
#       purchase_country customer_first_name customer_last_name  \
# 35704          EE. UU.                Sara            Foreman
# ...

# %%
df['purchase_state'].value_counts()
# Out:
# PR       69373
# CA       29223
# NY       11327
# TX        9103
# IL        7631
# FL        5456
# OH        4095
# PA        3824
# MI        3804
# NJ        3191
# AZ        3026
# GA        2503
# MD        2415
# NC        1992
# CO        1914
# VA        1849
# OR        1668
# MA        1607
# TN        1582
# NV        1440
# MO        1354
# HI        1248
# CT        1094
# UT         968
# NM         949
# LA         948
# WA         920
# WI         850
# MN         672
# SC         665
# IN         581
# DC         579
# KY         487
# KS         458
# DE         269
# RI         243
# WV         241
# OK         232
# ND         215
# ID         167
# AR         164
# MT          87
# IA          67
# AL          35
# 95758        2
# 91732        1
# Name: purchase_state, dtype: int64

# %%
df.loc[35704,'purchase_zipcode']="95758"

# %%
df.loc[46440,'purchase_zipcode']="95758"

# %%
df.loc[82511,'purchase_zipcode']="91732"

# %%
df.loc[35704,'purchase_state']="California"

# %%
df.loc[46440,'purchase_state']="California"

# %%
df.loc[82511,'purchase_state']="California"

# %%
df.isna().sum()
# Out:
# transaction_type            0
# actual_shipping_days        0
# scheduled_shipping_days     0
# earnings_per_order          0
# sales_per_customer          0
# delivery_status             0
# late_delivery               0
# category_id                 0
# category_name               0
# purchase_city               0
# purchase_country            0
# customer_first_name         0
# customer_last_name          0
# customer_segment            0
# purchase_state              0
# purchase_street             0
# purchase_zipcode            0
# department_category         0
# latitude                    0
# longitude                   0
# market_region               0
# order_city                  0
# order_country               0
# order_date                  0
# order_item_discount         0
# order_item_discount_rate    0
# order_item_rate             0
# order_item_profit_ratio     0
# order_item_quantity         0
# gross_sales_per_customer    0
# net_sales_per_customer      0
# ...

# %%
df.dtypes
# Out:
# transaction_type             object
# actual_shipping_days          int64
# scheduled_shipping_days       int64
# earnings_per_order          float64
# sales_per_customer          float64
# delivery_status              object
# late_delivery                 int64
# category_id                   int64
# category_name                object
# purchase_city                object
# purchase_country             object
# customer_first_name          object
# customer_last_name           object
# customer_segment             object
# purchase_state               object
# purchase_street              object
# purchase_zipcode             object
# department_category          object
# latitude                    float64
# longitude                   float64
# market_region                object
# order_city                   object
# order_country                object
# order_date                   object
# order_item_discount         float64
# order_item_discount_rate    float64
# ...

# %%
df['purchase_zipcode']=df['purchase_zipcode'].astype(int)

# %%
df['order_date'] = pd.to_datetime(df['order_date']).dt.strftime('%Y/%m/%d %H:%M')

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%Y/%m/%d %H:%M')

# %%
df['order_date']
# Out:
# 0        2018-01-31 22:56:00
# 1        2018-01-13 12:27:00
# 2        2018-01-13 12:06:00
# 3        2018-01-13 11:45:00
# 4        2018-01-13 11:24:00
#                  ...
# 180514   2016-01-16 03:40:00
# 180515   2016-01-16 01:34:00
# 180516   2016-01-15 21:00:00
# 180517   2016-01-15 20:18:00
# 180518   2016-01-15 18:54:00
# Name: order_date, Length: 180519, dtype: datetime64[ns]

# %%
df['order_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[['order_date','shipping_date']]
# Out:
#                 order_date     shipping_date
# 0      2018-01-31 22:56:00  02-03-2018 22:56
# 1      2018-01-13 12:27:00   1/18/2018 12:27
# 2      2018-01-13 12:06:00   1/17/2018 12:06
# 3      2018-01-13 11:45:00   1/16/2018 11:45
# 4      2018-01-13 11:24:00   1/15/2018 11:24
# ...                    ...               ...
# 180514 2016-01-16 03:40:00    1/20/2016 3:40
# 180515 2016-01-16 01:34:00    1/19/2016 1:34
# 180516 2016-01-15 21:00:00   1/20/2016 21:00
# 180517 2016-01-15 20:18:00   1/18/2016 20:18
# 180518 2016-01-15 18:54:00   1/19/2016 18:54
#
# [180519 rows x 2 columns]

# %%
df['shipping_date'] = pd.to_datetime(df['shipping_date']).dt.strftime('%Y/%m/%d %H:%M')

df['shipping_date'] = pd.to_datetime(df['shipping_date'], format='%Y/%m/%d %H:%M')

# %%
df['shipping_date']
# Out:
# 0        2018-02-03 22:56:00
# 1        2018-01-18 12:27:00
# 2        2018-01-17 12:06:00
# 3        2018-01-16 11:45:00
# 4        2018-01-15 11:24:00
#                  ...
# 180514   2016-01-20 03:40:00
# 180515   2016-01-19 01:34:00
# 180516   2016-01-20 21:00:00
# 180517   2016-01-18 20:18:00
# 180518   2016-01-19 18:54:00
# Name: shipping_date, Length: 180519, dtype: datetime64[ns]

# %%
#Calculating the percentage of repeatitions of 0's in each column
perct_0 = {column: '%2.2f' %(((df[column] == 0).sum()/df.shape[0])*100)+'%' for column in df.columns
                             if df[column].dtype == np.float64}

# %%
perct_0
# Out:
# {'earnings_per_order': '0.65%',
#  'sales_per_customer': '0.00%',
#  'latitude': '0.00%',
#  'longitude': '0.00%',
#  'order_item_discount': '5.56%',
#  'order_item_discount_rate': '5.56%',
#  'order_item_rate': '0.00%',
#  'order_item_profit_ratio': '0.65%',
#  'gross_sales_per_customer': '0.00%',
#  'net_sales_per_customer': '0.00%',
#  'net_profit_per_order': '0.65%'}

# %%
#Calculating the percentage of repeatitions of 0's in each column
perct_0 = {column: '%2.2f' %(((df[column] == 0).sum()/df.shape[0])*100)+'%' for column in df.columns
                             if df[column].dtype == np.int64}

# %%
perct_0
# Out:
# {'actual_shipping_days': '2.81%',
#  'scheduled_shipping_days': '5.39%',
#  'late_delivery': '45.17%',
#  'category_id': '0.00%',
#  'order_item_quantity': '0.00%',
#  'product_availability': '100.00%'}

# %%
nrows = 3
ncols = 3
fig, ax1 = plt.subplots(nrows, ncols, figsize = (15, 15))
sns.boxplot(df.earnings_per_order, ax = ax1[0,0])
sns.boxplot(df.sales_per_customer, ax = ax1[0,1])
sns.boxplot(df.order_item_discount, ax = ax1[0,2])
sns.boxplot(df.order_item_discount_rate, ax = ax1[1,0])
sns.boxplot(df.order_item_rate, ax = ax1[1,1])
sns.boxplot(df.order_item_profit_ratio, ax = ax1[1,2])
sns.boxplot(df.gross_sales_per_customer, ax = ax1[2,0])
sns.boxplot(df.net_sales_per_customer, ax = ax1[2,1])
sns.boxplot(df.net_profit_per_order, ax = ax1[2,2])
# Out:
# C:\Users\prite_ef\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prite_ef\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prite_ef\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.distplot(df.gross_sales_per_customer)
# Out:
# C:\Users\prite_ef\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gross_sales_per_customer', ylabel='Density'>

# %%
df
# Out:
#        transaction_type  actual_shipping_days  scheduled_shipping_days  \
# 0                 DEBIT                     3                        4
# 1              TRANSFER                     5                        4
# 2                  CASH                     4                        4
# 3                 DEBIT                     3                        4
# 4               PAYMENT                     2                        4
# ...                 ...                   ...                      ...
# 180514             CASH                     4                        4
# 180515            DEBIT                     3                        2
# 180516         TRANSFER                     5                        4
# 180517          PAYMENT                     3                        4
# 180518          PAYMENT                     4                        4
#
#         earnings_per_order  sales_per_customer   delivery_status  \
# ...

# %%
df['order_status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: order_status, dtype: int64

# %%
schema_df
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
file_path = "C:/Users/prite_ef/OneDrive/Documents/Pyhton Practice/Supply Chain Data/8gx2fvg2k6-5/DescriptionDataCoSupplyChain.csv"

schema_df = pd.read_csv(file_path, encoding='latin-1',index_col="FIELDS")
pd.set_option('display.max_colwidth', 2000)

# %%
    schema_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                     DESCRIPTION
# FIELDS
# Type                                                                                                                                                                                                                                                                                                                                                                                                :  Type of transaction made
# ...

# %%
schema_df.loc['Order Status']
# Out:
# DESCRIPTION    :  Order Status : COMPLETE , PENDING , CLOSED , PENDING_PAYMENT ,CANCELED , PROCESSING ,SUSPECTED_FRAUD ,ON_HOLD ,PAYMENT_REVIEW
# Name: Order Status, dtype: object

# %%
df.columns
# Out:
# Index(['transaction_type', 'actual_shipping_days', 'scheduled_shipping_days',
#        'earnings_per_order', 'sales_per_customer', 'delivery_status',
#        'late_delivery', 'category_id', 'category_name', 'purchase_city',
#        'purchase_country', 'customer_first_name', 'customer_last_name',
#        'customer_segment', 'purchase_state', 'purchase_street',
#        'purchase_zipcode', 'department_category', 'latitude', 'longitude',
#        'market_region', 'order_city', 'order_country', 'order_date',
#        'order_item_discount', 'order_item_discount_rate', 'order_item_rate',
#        'order_item_profit_ratio', 'order_item_quantity',
#        'gross_sales_per_customer', 'net_sales_per_customer',
#        'net_profit_per_order', 'order_region', 'order_state', 'order_status',
#        'product_name', 'product_availability', 'shipping_date',
#        'shipping_mode'],
#       dtype='object')

# %%
Updated_Col_names={
    "UpdatedColName": ['transaction_type', 'actual_shipping_days', 'scheduled_shipping_days',
       'earnings_per_order', 'sales_per_customer', 'delivery_status',
       'late_delivery', 'category_id', 'category_name', 'purchase_city',
       'purchase_country', 'Customer Email','customer_first_name','Customer Id', 'customer_last_name','Customer Password',
       'customer_segment', 'purchase_state', 'purchase_street',
       'purchase_zipcode','Department Id', 'department_category', 'latitude', 'longitude',
       'market_region', 'order_city', 'order_country','Order Customer Id', 'order_date', 'Order Id',
       'Order Item Cardprod Id', 
       'order_item_discount', 'order_item_discount_rate','Order Item Id', 'order_item_rate',
       'order_item_profit_ratio', 'order_item_quantity',
       'gross_sales_per_customer', 'net_sales_per_customer',
       'net_profit_per_order', 'order_region', 'order_state', 'order_status', 'Product Card Id', 'Product Category Id', 'Product Description',
       'Product Image',
       'product_name', 'Product Price','product_availability', 'shipping_date',
       'shipping_mode']
}

# %%
ff= pd.DataFrame(Updated_Col_names)

# %%
print(schema_df.shape)
print(ff.shape)
# Out:
# (52, 1)
# (52, 1)

# %%
schema_df["UpdatedColName"] = ff.values

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df.set_index("UpdatedColName",inplace=True)

# %%
schema_df
# Out:
#                                                  FIELDS  \
# UpdatedColName
# transaction_type                                   Type
# actual_shipping_days      Days for shipping (real)
# scheduled_shipping_days   Days for shipment (scheduled)
# earnings_per_order                    Benefit per order
# sales_per_customer                   Sales per customer
# delivery_status                         Delivery Status
# late_delivery             Late_delivery_risk
# category_id                                 Category Id
# category_name                             Category Name
# purchase_city                             Customer City
# purchase_country                       Customer Country
# Customer Email                           Customer Email
# customer_first_name                      Customer Fname
# Customer Id                                 Customer Id
# customer_last_name                       Customer Lname
# Customer Password                     Customer Password
# ...

# %%
schema_df.loc['order_status']
# Out:
# FIELDS                                                                                                                             Order Status
# DESCRIPTION    :  Order Status : COMPLETE , PENDING , CLOSED , PENDING_PAYMENT ,CANCELED , PROCESSING ,SUSPECTED_FRAUD ,ON_HOLD ,PAYMENT_REVIEW
# Name: order_status, dtype: object

# %%
ff.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
df.to_csv('MetadataCleaned.csv', index = False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\prite_ef\OneDrive\Documents\Pyhton Practice\Panda Demo\data

# %%
schema_df.to_csv('SchemaNew.csv', index = True)

# %%
dd=pd.read_csv('SchemaNew.csv')

# %%
dd
# Out:
#               UpdatedColName                         FIELDS  \
# 0           transaction_type                           Type
# 1       actual_shipping_days  Days for shipping (real)
# 2    scheduled_shipping_days  Days for shipment (scheduled)
# 3         earnings_per_order              Benefit per order
# 4         sales_per_customer             Sales per customer
# 5            delivery_status                Delivery Status
# 6              late_delivery  Late_delivery_risk
# 7                category_id                    Category Id
# 8              category_name                  Category Name
# 9              purchase_city                  Customer City
# 10          purchase_country               Customer Country
# 11            Customer Email                 Customer Email
# 12       customer_first_name                 Customer Fname
# 13               Customer Id                    Customer Id
# 14        customer_last_name                 Customer Lname
# ...

# %%
for col in df.columns:
    print(col)
    print(df[col].drop_duplicates())
# Out:
# transaction_type
# 0       DEBIT
# 1    TRANSFER
# 2        CASH
# 4     PAYMENT
# Name: transaction_type, dtype: object
# actual_shipping_days
# 0     3
# 1     5
# 2     4
# 4     2
# 5     6
# 19    0
# 38    1
# Name: actual_shipping_days, dtype: int64
# scheduled_shipping_days
# 0     4
# 6     1
# 8     2
# 19    0
# Name: scheduled_shipping_days, dtype: int64
# earnings_per_order
# 0          91.250000
# 1        -249.089996
# 2        -247.779999
# 3          22.860001
# 4         134.210007
#              ...
# 180229   -569.169983
# 180310   -246.490005
# 180331   -103.970001
# 180452   -237.589996
# 180498   -337.100006
# Name: earnings_per_order, Length: 21998, dtype: float64
# sales_per_customer
# 0          314.640015
# 1          311.359985
# 2          309.720001
# 3          304.809998
# 4          298.250000
#              ...
# 175116    1939.989990
# 175274      84.150002
# 176306     298.769989
# 179498     403.709992
# 179564     474.760010
# ...

# %%
df.apply(pd.Series.nunique)
# Out:
# transaction_type                4
# actual_shipping_days            7
# scheduled_shipping_days         4
# earnings_per_order          21998
# sales_per_customer           2927
# delivery_status                 4
# late_delivery                   2
# category_id                    51
# category_name                  50
# purchase_city                 563
# purchase_country                2
# customer_first_name           782
# customer_last_name           1110
# customer_segment                3
# purchase_state                 45
# purchase_street              7458
# purchase_zipcode              995
# department_category            11
# latitude                    11250
# longitude                    4487
# market_region                   5
# order_city                   3597
# order_country                 164
# order_date                  65752
# order_item_discount          1017
# order_item_discount_rate       18
# order_item_rate                75
# ...

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].drop_duplicates())
# Out:
# transaction_type
# 0       DEBIT
# 1    TRANSFER
# 2        CASH
# 4     PAYMENT
# Name: transaction_type, dtype: object
# delivery_status
# 0     Advance shipping
# 1        Late delivery
# 2     Shipping on time
# 5    Shipping canceled
# Name: delivery_status, dtype: object
# category_name
# 0              Sporting Goods
# 48                     Cleats
# 49              Shop By Sport
# 50            Women's Apparel
# 55                Electronics
# 56               Boxing & MMA
# 59           Cardio Equipment
# 61                   Trade-In
# 117          Kids' Golf Clubs
# 118        Hunting & Shooting
# 119       Baseball & Softball
# 138            Men's Footwear
# 143          Camping & Hiking
# 145      Consumer Electronics
# 146                  Cameras
# 152                 Computers
# 174                Basketball
# 175                    Soccer
# 191            Girls' Apparel
# 197               Accessories
# 234          Women's Clothing
# 243                    Crafts
# ...

# %%
df.columns
# Out:
# Index(['transaction_type', 'actual_shipping_days', 'scheduled_shipping_days',
#        'earnings_per_order', 'sales_per_customer', 'delivery_status',
#        'late_delivery', 'category_id', 'category_name', 'purchase_city',
#        'purchase_country', 'customer_first_name', 'customer_last_name',
#        'customer_segment', 'purchase_state', 'purchase_street',
#        'purchase_zipcode', 'department_category', 'latitude', 'longitude',
#        'market_region', 'order_city', 'order_country', 'order_date',
#        'order_item_discount', 'order_item_discount_rate', 'order_item_rate',
#        'order_item_profit_ratio', 'order_item_quantity',
#        'gross_sales_per_customer', 'net_sales_per_customer',
#        'net_profit_per_order', 'order_region', 'order_state', 'order_status',
#        'product_name', 'product_availability', 'shipping_date',
#        'shipping_mode'],
#       dtype='object')

# %%
df.loc[35704,'purchase_state']="CA"
df.loc[46440,'purchase_state']="CA"
df.loc[82511,'purchase_state']="CA"

# %%
df.nunique()
# Out:
# transaction_type                4
# actual_shipping_days            7
# scheduled_shipping_days         4
# earnings_per_order          21998
# sales_per_customer           2927
# delivery_status                 4
# late_delivery                   2
# category_id                    51
# category_name                  50
# purchase_city                 563
# purchase_country                2
# customer_first_name           782
# customer_last_name           1110
# customer_segment                3
# purchase_state                 44
# purchase_street              7458
# purchase_zipcode              995
# department_category            11
# latitude                    11250
# longitude                    4487
# market_region                   5
# order_city                   3597
# order_country                 164
# order_date                  65752
# order_item_discount          1017
# order_item_discount_rate       18
# order_item_rate                75
# ...

# %%
columns = ['transaction_type', 'actual_shipping_days', 'scheduled_shipping_days',
       'earnings_per_order', 'sales_per_customer', 'delivery_status',
       'late_delivery', 'category_id', 'category_name', 'purchase_city',
       'purchase_country', 'customer_first_name', 'customer_last_name',
       'customer_segment', 'purchase_state', 'purchase_street',
       'purchase_zipcode', 'department_category', 'latitude', 'longitude',
       'market_region', 'order_city', 'order_country', 'order_date',
       'order_item_discount', 'order_item_discount_rate', 'order_item_rate',
       'order_item_profit_ratio', 'order_item_quantity',
       'gross_sales_per_customer', 'net_sales_per_customer',
       'net_profit_per_order', 'order_region', 'order_state', 'order_status',
       'product_name', 'product_availability', 'shipping_date',
       'shipping_mode']

for column in columns:
    print(f'Unique values in {column} column:')
    print(df[column].unique())
    print()
# Out:
# Unique values in transaction_type column:
# ['DEBIT' 'TRANSFER' 'CASH' 'PAYMENT']
#
# Unique values in actual_shipping_days column:
# [3 5 4 2 6 0 1]
#
# Unique values in scheduled_shipping_days column:
# [4 1 2 0]
#
# Unique values in earnings_per_order column:
# [  91.25      -249.0899963 -247.7799988 ... -103.9700012 -237.5899963
#  -337.1000061]
#
# Unique values in sales_per_customer column:
# [314.6400146 311.3599854 309.7200012 ... 298.769989  403.7099915
#  474.7600098]
#
# Unique values in delivery_status column:
# ['Advance shipping' 'Late delivery' 'Shipping on time' 'Shipping canceled']
#
# Unique values in late_delivery column:
# [0 1]
#
# Unique values in category_id column:
# [73 17 29 24 13 12  9 41 37 38 44  3 18 43 65 62 64  4  2 26 40 76 66 70
#   6 11 16 36 10 63  5 60 45 59 67 61 68  7 72 69 71 75 35 34 33 32 31 30
#  74 48 46]
#
# Unique values in category_name column:
# ['Sporting Goods' 'Cleats' 'Shop By Sport' "Women's Apparel" 'Electronics'
# ...

# %%
df.drop_duplicates(subset=columns)
# Out:
#        transaction_type  actual_shipping_days  scheduled_shipping_days  \
# 0                 DEBIT                     3                        4
# 1              TRANSFER                     5                        4
# 2                  CASH                     4                        4
# 3                 DEBIT                     3                        4
# 4               PAYMENT                     2                        4
# ...                 ...                   ...                      ...
# 180514             CASH                     4                        4
# 180515            DEBIT                     3                        2
# 180516         TRANSFER                     5                        4
# 180517          PAYMENT                     3                        4
# 180518          PAYMENT                     4                        4
#
#         earnings_per_order  sales_per_customer   delivery_status  \
# ...

# %%
columns=['purchase_city','purchase_country','purchase_state','market_region','order_city','order_country','order_region','order_state']
for column in columns:
    print(f'Unique values in {column} column:')
    print(df[column].unique())
    print()
# Out:
# Unique values in purchase_city column:
# ['Caguas' 'San Jose' 'Los Angeles' 'Tonawanda' 'Miami' 'San Ramon'
#  'Freeport' 'Salinas' 'Peabody' 'Canovanas' 'Paramount' 'Mount Prospect'
#  'Long Beach' 'Rancho Cordova' 'Billings' 'Wilkes Barre' 'Roseville'
#  'Bellflower' 'Wheaton' 'Detroit' 'Dallas' 'Carlisle' 'Newark'
#  'Panorama City' 'Atlanta' 'Fremont' 'Rochester' 'Bayamon' 'Guayama'
#  'Juana Diaz' 'Fort Washington' 'Bakersfield' 'Corona' 'Cincinnati'
#  'Germantown' 'Carrollton' 'Houston' 'Ewa Beach' 'Lakewood' 'Rome' 'Vista'
#  'Fort Worth' 'Fond Du Lac' 'Philadelphia' 'Ontario' 'Oviedo' 'Buffalo'
#  'Honolulu' 'Oceanside' 'North Tonawanda' 'Clovis' 'Jamaica'
#  'Granite City' 'Medford' 'Pomona' 'Tempe' 'Santa Ana' 'York' 'Aurora'
#  'Simi Valley' 'Silver Spring' 'Saint Paul' 'San Antonio' 'Bronx'
#  'Greenville' 'Morristown' 'San Diego' 'Oxnard' 'Albuquerque' 'Amarillo'
#  'Lutz' 'Bend' 'East Brunswick' 'Lancaster' 'Hampton' 'New York'
# ...

# %%
# create a dictionary of country name translations
translations = {
    'Indonesia': 'Indonesia',
    'India': 'India',
    'Australia': 'Australia',
    'China': 'China',
    'Japón': 'Japan',
    'Corea del Sur': 'South Korea',
    'Singapur': 'Singapore',
    'Turquía': 'Turkey',
    'Mongolia': 'Mongolia',
    'Estados Unidos': 'United States',
    'Nigeria': 'Nigeria',
    'República Democrática del Congo': 'Democratic Republic of Congo',
    'Senegal': 'Senegal',
    'Marruecos': 'Morocco',
    'Alemania': 'Germany',
    'Francia': 'France',
    'Países Bajos': 'Netherlands',
    'Reino Unido': 'United Kingdom',
    'Guatemala': 'Guatemala',
    'El Salvador': 'El Salvador',
    'Panamá': 'Panama',
    'República Dominicana': 'Dominican Republic',
    'Venezuela': 'Venezuela',
    'Colombia': 'Colombia',
    'Honduras': 'Honduras',
    'Brasil': 'Brazil',
    'México': 'Mexico',
    'Uruguay': 'Uruguay',
    'Argentina': 'Argentina',
    'Cuba': 'Cuba',
    'Perú': 'Peru',
    'Nicaragua': 'Nicaragua',
    'Ecuador': 'Ecuador'
}

# loop through the 'order_country' column, replacing the current country name with the English translation from the dictionary
for i in range(len(df['order_country'])):
    df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])
# Out:
# C:\Users\prite_ef\AppData\Local\Temp/ipykernel_4488/1898948850.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])

# %%
columns=['order_country']
for column in columns:
    print(f'Unique values in {column} column:')
    print(df[column].unique())
    print()
# Out:
# Unique values in order_country column:
# ['Indonesia' 'India' 'Australia' 'China' 'Japan' 'South Korea' 'Singapore'
#  'Turkey' 'Mongolia' 'United States' 'Nigeria'
#  'Democratic Republic of Congo' 'Senegal' 'Morocco' 'Germany' 'France'
#  'Netherlands' 'United Kingdom' 'Guatemala' 'El Salvador' 'Panama'
#  'Dominican Republic' 'Venezuela' 'Colombia' 'Honduras' 'Brazil' 'Mexico'
#  'Uruguay' 'Argentina' 'Cuba' 'Peru' 'Nicaragua' 'Ecuador' 'Angola'
#  'Sudán' 'Somalia' 'Costa de Marfil' 'Egipto' 'Italia' 'España' 'Suecia'
#  'Austria' 'Canada' 'Madagascar' 'Argelia' 'Liberia' 'Zambia' 'Níger'
#  'SudAfrica' 'Mozambique' 'Tanzania' 'Ruanda' 'Israel' 'Nueva Zelanda'
#  'Bangladés' 'Tailandia' 'Irak' 'Arabia Saudí' 'Filipinas' 'Kazajistán'
#  'Irán' 'Myanmar (Birmania)' 'Uzbekistán' 'Benín' 'Camerún' 'Kenia' 'Togo'
#  'Ucrania' 'Polonia' 'Portugal' 'Rumania' 'Trinidad y Tobago' 'Afganistán'
#  'Pakistán' 'Vietnam' 'Malasia' 'Finlandia' 'Rusia' 'Irlanda' 'Noruega'
# ...

# %%
# create a dictionary of country name translations
translations = {
    'Angola': 'Angola',
    'Sudán': 'Sudan',
    'Somalia': 'Somalia',
    'Costa de Marfil': 'Ivory Coast',
    'Egipto': 'Egypt',
    'Italia': 'Italy',
    'España': 'Spain',
    'Suecia': 'Sweden',
    'Austria': 'Austria',
    'Canada': 'Canada',
    'Madagascar': 'Madagascar',
    'Argelia': 'Algeria',
    'Liberia': 'Liberia',
    'Zambia': 'Zambia',
    'Níger': 'Niger',
    'SudAfrica': 'South Africa',
    'Mozambique': 'Mozambique',
    'Tanzania': 'Tanzania',
    'Ruanda': 'Rwanda',
    'Israel': 'Israel',
    'Nueva Zelanda': 'New Zealand',
    'Bangladés': 'Bangladesh',
    'Tailandia': 'Thailand',
    'Irak': 'Iraq',
    'Arabia Saudí': 'Saudi Arabia',
    'Filipinas': 'Philippines',
    'Kazajistán': 'Kazakhstan',
    'Irán': 'Iran',
    'Myanmar (Birmania)': 'Myanmar (Burma)',
    'Uzbekistán': 'Uzbekistan',
    'Benín': 'Benin',
    'Camerún': 'Cameroon',
    'Kenia': 'Kenya',
    'Togo': 'Togo',
    'Ucrania': 'Ukraine',
    'Polonia': 'Poland',
    'Portugal': 'Portugal',
    'Rumania': 'Romania',
    'Trinidad y Tobago': 'Trinidad and Tobago',
    'Afganistán': 'Afghanistan'
}

# loop through the 'order_country' column, replacing the current country name with the English translation from the dictionary
for i in range(len(df['order_country'])):
    df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])
# Out:
# C:\Users\prite_ef\AppData\Local\Temp/ipykernel_4488/2617274813.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])

# %%
# create a dictionary of country name translations
translations = {
    'Pakistán': 'Pakistan',
    'Vietnam': 'Vietnam',
    'Malasia': 'Malaysia',
    'Finlandia': 'Finland',
    'Rusia': 'Russia',
    'Irlanda': 'Ireland',
    'Noruega': 'Norway',
    'Eslovaquia': 'Slovakia',
    'Bélgica': 'Belgium',
    'Bolivia': 'Bolivia',
    'Chile': 'Chile',
    'Jamaica': 'Jamaica',
    'Yemen': 'Yemen',
    'Ghana': 'Ghana',
    'Guinea': 'Guinea',
    'Etiopía': 'Ethiopia',
    'Bulgaria': 'Bulgaria',
    'Kirguistán': 'Kyrgyzstan',
    'Georgia': 'Georgia',
    'Nepal': 'Nepal',
    'Emiratos Árabes Unidos': 'United Arab Emirates',
    'Camboya': 'Cambodia',
    'Uganda': 'Uganda',
    'Lesoto': 'Lesotho',
    'Lituania': 'Lithuania',
    'Suiza': 'Switzerland',
    'Hungría': 'Hungary',
    'Dinamarca': 'Denmark',
    'Haití': 'Haiti',
    'Bielorrusia': 'Belarus',
    'Croacia': 'Croatia',
    'Laos': 'Laos',
    'Baréin': 'Bahrain',
    'Macedonia': 'Macedonia',
    'República Checa': 'Czech Republic',
    'Sri Lanka': 'Sri Lanka',
    'Zimbabue': 'Zimbabwe',
    'Eritrea': 'Eritrea',
    'Burkina Faso': 'Burkina Faso',
    'Costa Rica': 'Costa Rica',
    'Libia': 'Libya',
    'Barbados': 'Barbados',
    'Tayikistán': 'Tajikistan',
    'Siria': 'Syria'
}

# loop through the 'order_country' column, replacing the current country name with the English translation from the dictionary
for i in range(len(df['order_country'])):
    df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])
# Out:
# C:\Users\prite_ef\AppData\Local\Temp/ipykernel_4488/931510227.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])

# %%
# create a dictionary of country name translations
translations = {
    'Guadalupe': 'Guadeloupe',
    'Papúa Nueva Guinea': 'Papua New Guinea',
    'Azerbaiyán': 'Azerbaijan',
    'Turkmenistán': 'Turkmenistan',
    'Paraguay': 'Paraguay',
    'Jordania': 'Jordan',
    'Hong Kong': 'Hong Kong',
    'Martinica': 'Martinique',
    'Moldavia': 'Moldova',
    'Qatar': 'Qatar',
    'Mali': 'Mali',
    'Albania': 'Albania',
    'República del Congo': 'Republic of Congo',
    'Bosnia y Herzegovina': 'Bosnia and Herzegovina',
    'Omán': 'Oman',
    'Túnez': 'Tunisia',
    'Sierra Leona': 'Sierra Leone',
    'Yibuti': 'Djibouti',
    'Burundi': 'Burundi',
    'Montenegro': 'Montenegro',
    'Gabón': 'Gabon',
    'Sudán del Sur': 'South Sudan',
    'Luxemburgo': 'Luxembourg',
    'Namibia': 'Namibia',
    'Mauritania': 'Mauritania',
    'Grecia': 'Greece',
    'Suazilandia': 'Swaziland',
    'Guyana': 'Guyana',
    'Guayana Francesa': 'French Guiana',
    'República Centroafricana': 'Central African Republic',
    'Taiwán': 'Taiwan',
    'Estonia': 'Estonia',
    'Líbano': 'Lebanon',
    'Chipre': 'Cyprus',
    'Guinea-Bissau': 'Guinea-Bissau',
    'Surinam': 'Suriname',
    'Belice': 'Belize',
    'Eslovenia': 'Slovenia',
    'República de Gambia': 'Gambia',
    'Botsuana': 'Botswana',
    'Armenia': 'Armenia',
    'Guinea Ecuatorial': 'Equatorial Guinea',
    'Kuwait': 'Kuwait',
    'Bután': 'Bhutan',
    'Chad': 'Chad',
    'Serbia': 'Serbia',
    'Sáhara Occidental': 'Western Sahara'
}

# loop through the 'order_country' column, replacing the current country name with the English translation from the dictionary
for i in range(len(df['order_country'])):
    df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])
# Out:
# C:\Users\prite_ef\AppData\Local\Temp/ipykernel_4488/1180684048.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order_country'][i] = translations.get(df['order_country'][i], df['order_country'][i])

# %%
columns=['order_country']
for column in columns:
    print(f'Unique values in {column} column:')
    print(df[column].unique())
    print()
# Out:
# Unique values in order_country column:
# ['Indonesia' 'India' 'Australia' 'China' 'Japan' 'South Korea' 'Singapore'
#  'Turkey' 'Mongolia' 'United States' 'Nigeria'
#  'Democratic Republic of Congo' 'Senegal' 'Morocco' 'Germany' 'France'
#  'Netherlands' 'United Kingdom' 'Guatemala' 'El Salvador' 'Panama'
#  'Dominican Republic' 'Venezuela' 'Colombia' 'Honduras' 'Brazil' 'Mexico'
#  'Uruguay' 'Argentina' 'Cuba' 'Peru' 'Nicaragua' 'Ecuador' 'Angola'
#  'Sudan' 'Somalia' 'Ivory Coast' 'Egypt' 'Italy' 'Spain' 'Sweden'
#  'Austria' 'Canada' 'Madagascar' 'Algeria' 'Liberia' 'Zambia' 'Niger'
#  'South Africa' 'Mozambique' 'Tanzania' 'Rwanda' 'Israel' 'New Zealand'
#  'Bangladesh' 'Thailand' 'Iraq' 'Saudi Arabia' 'Philippines' 'Kazakhstan'
#  'Iran' 'Myanmar (Burma)' 'Uzbekistan' 'Benin' 'Cameroon' 'Kenya' 'Togo'
#  'Ukraine' 'Poland' 'Portugal' 'Romania' 'Trinidad and Tobago'
#  'Afghanistan' 'Pakistan' 'Vietnam' 'Malaysia' 'Finland' 'Russia'
# ...

# %%
# create a dictionary of country name translations
translations = {
    'EE. UU.': 'United States'
}

# loop through the 'order_country' column, replacing the current country name with the English translation from the dictionary
for i in range(len(df['order_country'])):
    df['purchase_country'][i] = translations.get(df['purchase_country'][i], df['purchase_country'][i])
# Out:
# C:\Users\prite_ef\AppData\Local\Temp/ipykernel_4488/3073971296.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['purchase_country'][i] = translations.get(df['purchase_country'][i], df['purchase_country'][i])

# %%
df.to_csv('MetadataCleanedFinal.csv', index = False)
schema_df.to_csv('SchemaNewFinal.csv', index = True)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\prite_ef\OneDrive\Documents\Pyhton Practice\Panda Demo\data

# %%
unit_price = pd.DataFrame(merged_df1['unit_price'])

# %%
week_list = [up]*len(week)
new_df = pd.concat([df.assign(date=date) for df, date in zip(week_list,week['date'])])
